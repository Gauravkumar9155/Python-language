# %%
import pandas as pd
std = pd.read_csv('Countries with GDP.txt')
print(std)
print('List of countries:')
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       List of countries:
# ...

# %%
std.describe()

# %%
b = std.transpose()
b
# Out:
#                                  'Algeria' GDP values for each country:  \
#                                   'Angola'                          NaN
#                                'Argentina'                          NaN
#                                'Australia'                          NaN
#                                  'Austria'                          NaN
#                                  'Bahamas'                          NaN
#                               'Bangladesh'                          NaN
#                                  'Belarus'                          NaN
#                                  'Belgium'                          NaN
#                                   'Bhutan'                          NaN
#                                   'Brazil'                          NaN
#                                 'Bulgaria'                          NaN
#                                 'Cambodia'                          NaN
# ...

# %%
import pandas as pd
std = pd.read_excel("Olympic 2012 Medal Tally.xlsx")
print(std)
# Out:
#          Country Country Code    Year Medal Tally Unnamed: 4 Unnamed: 5
# 0            NaN          NaN     NaN        Gold     Silver     Bronze
# 1  Great Britain          GBR  2012.0          29         17         19
# 2         China           CHN  2012.0          38         28         22
# 3         Russia          RUS  2012.0          24         25         32
# 4  United States           US  2012.0          46         28         29
# 5          Korea          KOR  2012.0          13          8          7
# 6          Japan          JPN  2012.0           7         14         17
# 7        Germany          GER  2012.0          11         11         14

# %%
import pandas as pd
data = pd.read_excel("domestic tourist visits.xlsx")
data
# Out:
#     Year  Domestic Tourist Visitors(million)
# 0   2000                              220.36
# 1   2001                              236.47
# 2   2002                              269.60
# 3   2003                              309.04
# 4   2004                              366.27
# 5   2005                              391.95
# 6   2006                              462.31
# 7   2007                              526.43
# 8   2008                              563.03
# 9   2009                              668.80
# 10  2010                              747.70
# 11  2011                              864.53
# 12  2012                             1036.35
# 13  2013                             1145.28
# 14  2014                             1282.80
# 15  2015                             1431.97
# 16  2016                             1615.39
# 17  2017                             1657.55
# 18  2018                             1853.79
# 19  2019                             2321.98

# %%
data.tail(10)
# Out:
#     Year  Domestic Tourist Visitors(million)
# 10  2010                              747.70
# 11  2011                              864.53
# 12  2012                             1036.35
# 13  2013                             1145.28
# 14  2014                             1282.80
# 15  2015                             1431.97
# 16  2016                             1615.39
# 17  2017                             1657.55
# 18  2018                             1853.79
# 19  2019                             2321.98
